# %% [markdown]
# <a href="https://colab.research.google.com/github/jnetoass/jnetoass.github.io/blob/master/formula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! mkdir /content/.kaggle

# %%
import json

token = {"username":"netoassunao","key":"947383512cf2cfd01f88b368b68752a7"}

with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json
#Configure the file
# !kaggle config set -n path -v{/content}
# Out:
# ...
# - path is now set to: {/content}

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d rohanrao/formula-1-world-championship-1950-2020 -p /content
# Out:
# ...
#   0% 0.00/5.32M [00:00<?, ?B/s]
# 100% 5.32M/5.32M [00:00<00:00, 86.4MB/s]

# %%
import os
import zipfile

local_zip = '/content/formula-1-world-championship-1950-2020.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/formula-1-world-championship-1950-2020')
zip_ref.close()

# %%
import numpy as np
import pandas as pd
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore')

# %%
circuitos = pd.read_csv('/formula-1-world-championship-1950-2020/circuits.csv')

# %%
circuitos.head()
# Out:
#    circuitId  ...                                                url
# 0          1  ...  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1          2  ...  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2          3  ...  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3          4  ...  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4          5  ...         http://en.wikipedia.org/wiki/Istanbul_Park
#
# [5 rows x 9 columns]

# %%
construtor_resDF = pd.read_csv('/formula-1-world-championship-1950-2020/constructor_results.csv')
construtor_resDF
# Out:
#        constructorResultsId  raceId  constructorId  points status
# 0                         1      18              1    14.0     \N
# 1                         2      18              2     8.0     \N
# 2                         3      18              3     9.0     \N
# 3                         4      18              4     5.0     \N
# 4                         5      18              5     2.0     \N
# ...                     ...     ...            ...     ...    ...
# 11765                 16265    1055            213     1.0     \N
# 11766                 16266    1055            117     0.0     \N
# 11767                 16267    1055             51     0.0     \N
# 11768                 16268    1055              3     0.0     \N
# 11769                 16269    1055            210     0.0     \N
#
# [11770 rows x 5 columns]

# %%
#print(constructors_stdDF['constructorId'].unique())
#print(construtor_resDF['constructorId'].unique())

print(len(constructorsDF['constructorId'].unique().tolist()))
print(len(construtor_resDF['constructorId'].unique().tolist()))
print(len(constructors_stdDF['constructorId'].unique().tolist()))
# Out:
# 211
# 175
# 159

# %%
constructors_stdDF = pd.read_csv('/formula-1-world-championship-1950-2020/constructor_standings.csv')
constructors_stdDF.head()
# Out:
#    constructorStandingsId  raceId  constructorId  ...  position  positionText wins
# 0                       1      18              1  ...         1             1    1
# 1                       2      18              2  ...         3             3    0
# 2                       3      18              3  ...         2             2    0
# 3                       4      18              4  ...         4             4    0
# 4                       5      18              5  ...         5             5    0
#
# [5 rows x 7 columns]

# %%
constructorsDF = pd.read_csv('/formula-1-world-championship-1950-2020/constructors.csv')
constructorsDF
# Out:
#      constructorId  ...                                                url
# 0                1  ...               http://en.wikipedia.org/wiki/McLaren
# 1                2  ...            http://en.wikipedia.org/wiki/BMW_Sauber
# 2                3  ...  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3                4  ...  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4                5  ...   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# ..             ...  ...                                                ...
# 206            209  ...      http://en.wikipedia.org/wiki/Manor_Motorsport
# 207            210  ...          http://en.wikipedia.org/wiki/Haas_F1_Team
# 208            211  ...  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 209            213  ...   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 210            214  ...        http://en.wikipedia.org/wiki/Alpine_F1_Team
#
# [211 rows x 5 columns]

# %%
dfteste = pd.merge(construtor_resDF,constructors_stdDF,on='constructorId')
dfteste.head()
# Out:
#    constructorResultsId  raceId_x  constructorId  ...  position positionText  wins
# 0                     1        18              1  ...         1            1     1
# 1                     1        18              1  ...         1            1     1
# 2                     1        18              1  ...         3            3     1
# 3                     1        18              1  ...         3            3     1
# 4                     1        18              1  ...         3            3     1
#
# [5 rows x 11 columns]

# %%
len(dfteste['constructorId'].unique().tolist())
# Out:
# 159

# %%
dfteste2 = pd.merge(dfteste,constructorsDF,on='constructorId')
dfteste2
# Out:
#          constructorResultsId  ...                                          url
# 0                           1  ...         http://en.wikipedia.org/wiki/McLaren
# 1                           1  ...         http://en.wikipedia.org/wiki/McLaren
# 2                           1  ...         http://en.wikipedia.org/wiki/McLaren
# 3                           1  ...         http://en.wikipedia.org/wiki/McLaren
# 4                           1  ...         http://en.wikipedia.org/wiki/McLaren
# ...                       ...  ...                                          ...
# 4121450                 16264  ...  http://en.wikipedia.org/wiki/Alpine_F1_Team
# 4121451                 16264  ...  http://en.wikipedia.org/wiki/Alpine_F1_Team
# 4121452                 16264  ...  http://en.wikipedia.org/wiki/Alpine_F1_Team
# 4121453                 16264  ...  http://en.wikipedia.org/wiki/Alpine_F1_Team
# 4121454                 16264  ...  http://en.wikipedia.org/wiki/Alpine_F1_Team
#
# ...

# %%
dfteste2 = dfteste2.drop(columns=['status','positionText'])

# %%
dfteste2.head()
# Out:
#    constructorResultsId  ...                                   url
# 0                     1  ...  http://en.wikipedia.org/wiki/McLaren
# 1                     1  ...  http://en.wikipedia.org/wiki/McLaren
# 2                     1  ...  http://en.wikipedia.org/wiki/McLaren
# 3                     1  ...  http://en.wikipedia.org/wiki/McLaren
# 4                     1  ...  http://en.wikipedia.org/wiki/McLaren
#
# [5 rows x 13 columns]

# %%
len(dfteste2['constructorId'].unique().tolist())
# Out:
# 159

# %%
dfteste2.loc[dfteste2['nationality'] == 'Brazilian']
# Out:
#          constructorResultsId  ...                                                url
# 3886534                  5746  ...  http://en.wikipedia.org/wiki/Fittipaldi_%28con...
# 3886535                  5746  ...  http://en.wikipedia.org/wiki/Fittipaldi_%28con...
# 3886536                  5746  ...  http://en.wikipedia.org/wiki/Fittipaldi_%28con...
# 3886537                  5746  ...  http://en.wikipedia.org/wiki/Fittipaldi_%28con...
# 3886538                  5746  ...  http://en.wikipedia.org/wiki/Fittipaldi_%28con...
# ...                       ...  ...                                                ...
# 3901166                 13844  ...  http://en.wikipedia.org/wiki/Fittipaldi_%28con...
# 3901167                 13844  ...  http://en.wikipedia.org/wiki/Fittipaldi_%28con...
# 3901168                 13844  ...  http://en.wikipedia.org/wiki/Fittipaldi_%28con...
# 3901169                 13844  ...  http://en.wikipedia.org/wiki/Fittipaldi_%28con...
# ...

# %%
dfteste2.head()
# Out:
#    constructorResultsId  ...                                   url
# 0                     1  ...  http://en.wikipedia.org/wiki/McLaren
# 1                     1  ...  http://en.wikipedia.org/wiki/McLaren
# 2                     1  ...  http://en.wikipedia.org/wiki/McLaren
# 3                     1  ...  http://en.wikipedia.org/wiki/McLaren
# 4                     1  ...  http://en.wikipedia.org/wiki/McLaren
#
# [5 rows x 13 columns]

# %%
seasonsDF = pd.read_csv('/formula-1-world-championship-1950-2020/seasons.csv')
racesDF = pd.read_csv('/formula-1-world-championship-1950-2020/races.csv')

# %%
racesDF.head()
# Out:
#    raceId  year  ...      time                                                url
# 0       1  2009  ...  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1       2  2009  ...  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2       3  2009  ...  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3       4  2009  ...  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4       5  2009  ...  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...
#
# [5 rows x 8 columns]

# %%
dfteste3 = pd.merge(racesDF,circuitos,on='circuitId')
dfteste3
# Out:
#       raceId  year  ...  alt                                              url_y
# 0          1  2009  ...   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1         18  2008  ...   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 2         36  2007  ...   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 3         55  2006  ...   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 4         71  2005  ...   10  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# ...      ...   ...  ...  ...                                                ...
# 1053    1057  2021  ...   -7     http://en.wikipedia.org/wiki/Baku_City_Circuit
# 1054    1039  2020  ...  255       http://en.wikipedia.org/wiki/Mugello_Circuit
# 1055    1042  2020  ...  108  http://en.wikipedia.org/wiki/Algarve_Internati...
# 1056    1054  2021  ...  108  http://en.wikipedia.org/wiki/Algarve_Internati...
# 1057    1072  2021  ...   15  http://en.wikipedia.org/wiki/Jeddah_Street_Cir...
#
# ...

# %%
dfteste3 = dfteste3.drop(columns=['url_x','url_y','name_y',])

# %%
dfteste3.head()
# Out:
#    raceId  year  round  circuitId  ...    country      lat      lng alt
# 0       1  2009      1          1  ...  Australia -37.8497  144.968  10
# 1      18  2008      1          1  ...  Australia -37.8497  144.968  10
# 2      36  2007      1          1  ...  Australia -37.8497  144.968  10
# 3      55  2006      3          1  ...  Australia -37.8497  144.968  10
# 4      71  2005      1          1  ...  Australia -37.8497  144.968  10
#
# [5 rows x 13 columns]

# %%
dfteste3['country'][dfteste3['year'] == 2009].unique()
# Out:
# array(['Australia', 'Malaysia', 'China', 'Bahrain', 'Spain', 'Monaco',
#        'Turkey', 'UK', 'Germany', 'Hungary', 'Belgium', 'Italy',
#        'Singapore', 'Japan', 'Brazil', 'UAE'], dtype=object)

# %%
dfteste3['location'][dfteste3['year'] == 2009].unique()
# Out:
# array(['Melbourne', 'Kuala Lumpur', 'Shanghai', 'Sakhir', 'Montmeló',
#        'Monte-Carlo', 'Istanbul', 'Silverstone', 'Nürburg', 'Budapest',
#        'Valencia', 'Spa', 'Monza', 'Marina Bay', 'Suzuka', 'São Paulo',
#        'Abu Dhabi'], dtype=object)

# %%
dfteste3['location'][dfteste3['location'] == 'São Paulo'].value_counts()
# Out:
# São Paulo    38
# Name: location, dtype: int64

# %%
fig = go.Figure(data=[go.Bar(
    x=dfteste3.sort_values(by=['location'])['location'].unique(),
    y=dfteste3.groupby('location')['location'].value_counts()
)])
fig.update_layout(title={ 
                  'text': "Corridas por cidades",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'},
                  yaxis=dict(
                            title='frequência',
                            titlefont_size=16,
                            tickfont_size=14),
                  xaxis=dict(
                            title='cidade',
                            titlefont_size=16,
                            tickfont_size=14),
                  template = "plotly_dark"
                  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="12d407dc-7f60-4d6b-a99f-3289c12c1770" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("12d407dc-7f60-4d6b-a99f-3289c12c1770")) {
#                     Plotly.newPlot(
#                         '12d407dc-7f60-4d6b-a99f-3289c12c1770',
# ...

# %%
dups_color = dfteste3.pivot_table(index=['location'], aggfunc='size')
dups_color
# Out:
# location
# Abu Dhabi         13
# Adelaide          11
# Anderstorp         6
# Austin             9
# Baku               5
#                   ..
# São Paulo         38
# Uttar Pradesh      3
# Valencia           5
# Yeongam County     4
# Zandvoort         31
# Length: 72, dtype: int64

# %%
#dfteste3['location'].value_counts()
#dfteste3.groupby('location')['location'].value_counts()
dfteste3.sort_values(by=['location'])['location'].unique()
# Out:
# array(['Abu Dhabi', 'Adelaide', 'Anderstorp', 'Austin', 'Baku',
#        'Barcelona', 'Berlin', 'Bern', 'Brussels', 'Budapest',
#        'Buenos Aires', 'California', 'Casablanca', 'Castle Donington',
#        'Clermont-Ferrand', 'Dallas', 'Detroit', 'Dijon',
#        'Eastern Cape Province', 'Estoril', 'Florida', 'Heusden-Zolder',
#        'Hockenheim', 'Imola', 'Indianapolis', 'Istanbul', 'Jeddah',
#        'Jerez de la Frontera', 'Kent', 'Kuala Lumpur', 'Le Castellet',
#        'Le Mans', 'Lisbon', 'Liverpool', 'Madrid', 'Magny Cours',
#        'Marina Bay', 'Melbourne', 'Mexico City', 'Midrand', 'Monte-Carlo',
#        'Montmeló', 'Montreal', 'Monza', 'Mugello', 'Nevada',
#        'New York State', 'Nürburg', 'Okayama', 'Ontario', 'Oporto',
#        'Oyama', 'Pescara', 'Phoenix', 'Portimão', 'Quebec', 'Reims',
#        'Rio de Janeiro', 'Rouen', 'Sakhir', 'Shanghai', 'Silverstone',
#        'Sochi', 'Spa', 'Spielburg', 'Styria', 'Suzuka', 'São Paulo',
# ...

# %%
fig = go.Figure(data=[go.Bar(
    x=dfteste3.sort_values(by=['country'])['country'].unique(),
    y=dfteste3.groupby('country')['country'].value_counts()
)])
fig.update_layout(title={
        'text': "Total de Corridas por Países",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}, 
                  yaxis=dict(
                            titlefont_size=16,
                            tickfont_size=14),
                  xaxis=dict(
                            title='País',
                            titlefont_size=16,
                            tickfont_size=14),
                  template = "plotly_dark"
                  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b7dab29d-d3f4-4393-8b26-10d01866e888" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b7dab29d-d3f4-4393-8b26-10d01866e888")) {
#                     Plotly.newPlot(
#                         'b7dab29d-d3f4-4393-8b26-10d01866e888',
# ...

# %%
qualyDF = pd.read_csv('/formula-1-world-championship-1950-2020/qualifying.csv')
qualyDF.head()
# Out:
#    qualifyId  raceId  driverId  ...        q1        q2        q3
# 0          1      18         1  ...  1:26.572  1:25.187  1:26.714
# 1          2      18         9  ...  1:26.103  1:25.315  1:26.869
# 2          3      18         5  ...  1:25.664  1:25.452  1:27.079
# 3          4      18        13  ...  1:25.994  1:25.691  1:27.178
# 4          5      18         2  ...  1:25.960  1:25.518  1:27.236
#
# [5 rows x 9 columns]

# %%
dfteste4 = pd.merge(dfteste3,qualyDF,on='raceId')
dfteste4.head()
# Out:
#    raceId  year  round  circuitId  ... position        q1        q2        q3
# 0       1  2009      1          1  ...        1  1:25.211  1:24.855  1:26.202
# 1       1  2009      1          1  ...        2  1:25.006  1:24.783  1:26.505
# 2       1  2009      1          1  ...        3  1:25.938  1:25.121  1:26.830
# 3       1  2009      1          1  ...        4  1:25.922  1:25.152  1:26.914
# 4       1  2009      1          1  ...        5  1:25.846  1:25.123  1:26.973
#
# [5 rows x 21 columns]

# %%
dfteste4 = dfteste4.drop(columns=['url_x','url_y','name_y',])
dfteste4.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-6591fc9eb58e> in <module>()
# ----> 1 dfteste4 = dfteste4.drop(columns=['url_x','url_y','name_y',])
#       2 dfteste4.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
#len(dfteste4['driverId'].unique())
len(driversDF['driverId'].unique())
# Out:
# 853

# %%
driversDF = pd.read_csv('/formula-1-world-championship-1950-2020/drivers.csv')
driversDF = driversDF.drop(columns=['url'])
driversDF.head()
dfteste5 = pd.merge(dfteste4,driversDF,on='driverId')
dfteste5.head()
# Out:
#    raceId  year  round  circuitId  ... forename surname         dob nationality
# 0       1  2009      1          1  ...   Jenson  Button  1980-01-19     British
# 1      18  2008      1          1  ...   Jenson  Button  1980-01-19     British
# 2      36  2007      1          1  ...   Jenson  Button  1980-01-19     British
# 3      55  2006      3          1  ...   Jenson  Button  1980-01-19     British
# 4      71  2005      1          1  ...   Jenson  Button  1980-01-19     British
#
# [5 rows x 28 columns]

# %%
pitsDF = pd.read_csv('/formula-1-world-championship-1950-2020/lap_times.csv')
pitsDF.head()
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
dfteste6 = pd.merge(dfteste5,pitsDF,on='raceId')
dfteste6.head()
# Out:
#    raceId  year  round  circuitId  ... lap position_y    time_y milliseconds
# 0       1  2009      1          1  ...   1         13  1:49.088       109088
# 1       1  2009      1          1  ...   2         12  1:33.740        93740
# 2       1  2009      1          1  ...   3         11  1:31.600        91600
# 3       1  2009      1          1  ...   4         10  1:31.067        91067
# 4       1  2009      1          1  ...   5         10  1:32.129        92129
#
# [5 rows x 33 columns]

# %%
dfteste6.drop_duplicates(keep=False,inplace=True)

# %%
dfteste6
# Out:
#          raceId  year  round  ...  position_y    time_y milliseconds
# 0             1  2009      1  ...          13  1:49.088       109088
# 1             1  2009      1  ...          12  1:33.740        93740
# 2             1  2009      1  ...          11  1:31.600        91600
# 3             1  2009      1  ...          10  1:31.067        91067
# 4             1  2009      1  ...          10  1:32.129        92129
# ...         ...   ...    ...  ...         ...       ...          ...
# 8756988    1054  2021      3  ...          19  1:26.972        86972
# 8756989    1054  2021      3  ...          19  1:23.725        83725
# 8756990    1054  2021      3  ...          19  1:27.453        87453
# 8756991    1054  2021      3  ...          19  1:25.713        85713
# 8756992    1054  2021      3  ...          19  1:23.641        83641
#
# [8756993 rows x 33 columns]

# %%
resulDF = pd.read_csv('/formula-1-world-championship-1950-2020/results.csv')
resulDF.head()
# Out:
#    resultId  raceId  driverId  ...  fastestLapTime fastestLapSpeed  statusId
# 0         1      18         1  ...        1:27.452         218.300         1
# 1         2      18         2  ...        1:27.739         217.586         1
# 2         3      18         3  ...        1:28.090         216.719         1
# 3         4      18         4  ...        1:28.603         215.464         1
# 4         5      18         5  ...        1:27.418         218.385         1
#
# [5 rows x 18 columns]

# %%
dfresul = pd.merge(resulDF,driversDF,on='driverId')
#dfresul.head()

# %%
dfresulcons = pd.merge(dfresul,racesDF,on='raceId')
dfresulcons.head()
# Out:
#    resultId  ...                                                url
# 0         1  ...  http://en.wikipedia.org/wiki/2008_Australian_G...
# 1         2  ...  http://en.wikipedia.org/wiki/2008_Australian_G...
# 2         3  ...  http://en.wikipedia.org/wiki/2008_Australian_G...
# 3         4  ...  http://en.wikipedia.org/wiki/2008_Australian_G...
# 4         5  ...  http://en.wikipedia.org/wiki/2008_Australian_G...
#
# [5 rows x 32 columns]

# %%
dfresulrac = pd.merge(dfresulcons,constructorsDF,on='constructorId')
dfresulrac.head()
# Out:
#    resultId  raceId  ...  nationality_y                                 url_y
# 0         1      18  ...        British  http://en.wikipedia.org/wiki/McLaren
# 1         5      18  ...        British  http://en.wikipedia.org/wiki/McLaren
# 2        27      19  ...        British  http://en.wikipedia.org/wiki/McLaren
# 3        25      19  ...        British  http://en.wikipedia.org/wiki/McLaren
# 4        57      20  ...        British  http://en.wikipedia.org/wiki/McLaren
#
# [5 rows x 36 columns]

# %%
teste1 = dfresulrac[(dfresulrac['year']== 2008) & (dfresulrac['name_x']== 'Australian Grand Prix')]

# %%
teste2 = dfresulrac[(dfresulrac['year']== 2008) & (dfresulrac['driverRef']== 'hamilton')]
teste2
# Out:
#     resultId  raceId  ...  nationality_y                                 url_y
# 0          1      18  ...        British  http://en.wikipedia.org/wiki/McLaren
# 2         27      19  ...        British  http://en.wikipedia.org/wiki/McLaren
# 4         57      20  ...        British  http://en.wikipedia.org/wiki/McLaren
# 6         69      21  ...        British  http://en.wikipedia.org/wiki/McLaren
# 8         90      22  ...        British  http://en.wikipedia.org/wiki/McLaren
# 10       109      23  ...        British  http://en.wikipedia.org/wiki/McLaren
# 12       147      24  ...        British  http://en.wikipedia.org/wiki/McLaren
# 14       158      25  ...        British  http://en.wikipedia.org/wiki/McLaren
# 16       169      26  ...        British  http://en.wikipedia.org/wiki/McLaren
# 18       189      27  ...        British  http://en.wikipedia.org/wiki/McLaren
# 20       213      28  ...        British  http://en.wikipedia.org/wiki/McLaren
# ...

# %%
fig = go.Figure(data=[go.Scatter(
    x=teste2['name_x'],
    y=teste2['points'],
    hovertext=teste2['position']
)])
fig.update_layout(title={
        'text': "Desempenho de Lewis Hamilton 2008",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}, 
                  yaxis=dict(
                            title='Pontos',
                            titlefont_size=16,
                            tickfont_size=14),
                  xaxis=dict(
                            title='Grande Prêmio',
                            titlefont_size=16,
                            tickfont_size=14),
                  template = "plotly_dark"
                  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c1a787e9-0cc5-4bd2-8b4b-513d75c01cea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1a787e9-0cc5-4bd2-8b4b-513d75c01cea")) {
#                     Plotly.newPlot(
#                         'c1a787e9-0cc5-4bd2-8b4b-513d75c01cea',
# ...

# %%
fig = go.Figure()
# Create and style traces
fig.add_trace(go.Scatter(x=teste2['name_x'], y=teste2['points'], name='hamilton', hovertext=teste2['position'],
                         ))
fig.add_trace(go.Scatter(x= dfresulrac[(dfresulrac['year']== 2008) & (dfresulrac['driverRef']== 'massa')]['name_x'], y= dfresulrac[(dfresulrac['year']== 2008) & (dfresulrac['driverRef']== 'massa')]['points'], name = 'Massa',hovertext=dfresulrac[(dfresulrac['year']== 2008) & (dfresulrac['driverRef']== 'massa')]['position'],
                         ))

fig.update_layout(title={
        'text': "Desempenho de Lewis Hamilton x Felipe Massa 2008",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}, 
                  yaxis=dict(
                            title='Pontos',
                            titlefont_size=16,
                            tickfont_size=14),
                  xaxis=dict(
                            title='Grande Prêmio',
                            titlefont_size=16,
                            tickfont_size=14),
                  template = "plotly_dark",
                  hoverlabel=dict(
        bgcolor="white",
        font_size=10,
        font_family="Rockwell"
    )
                  )


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0c321c8f-66c4-467e-8ddb-b8c4946e91c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0c321c8f-66c4-467e-8ddb-b8c4946e91c1")) {
#                     Plotly.newPlot(
#                         '0c321c8f-66c4-467e-8ddb-b8c4946e91c1',
# ...

# %%
dfresulrac.groupby(by=[(dfresulrac['year']== 2008),'driverRef'])['points'].sum()
# Out:
# year   driverRef
# False  Cannoc        0.0
#        Changy        0.0
#        abate         0.0
#        abecassis     0.0
#        acheson       0.0
#                     ...
# True   sato          0.0
#        sutil         0.0
#        trulli       31.0
#        vettel       35.0
#        webber       21.0
# Name: points, Length: 875, dtype: float64

# %%
dfresulrac[(dfresulrac['year']== 2008)].groupby('driverRef')['points'].sum()
# Out:
# driverRef
# alonso         61.0
# barrichello    11.0
# bourdais        4.0
# button          3.0
# coulthard       8.0
# davidson        0.0
# fisichella      0.0
# glock          25.0
# hamilton       98.0
# heidfeld       60.0
# kovalainen     53.0
# kubica         75.0
# massa          97.0
# nakajima        9.0
# piquet_jr      19.0
# raikkonen      75.0
# rosberg        17.0
# sato            0.0
# sutil           0.0
# trulli         31.0
# vettel         35.0
# webber         21.0
# Name: points, dtype: float64

# %%
fig = go.Figure(data=[go.Bar(
    x=dfresulrac[(dfresulrac['year']== 2008)].sort_values(by=['driverRef'])['driverRef'].unique(),
    y=dfresulrac[(dfresulrac['year']== 2008)].groupby('driverRef')['points'].sum(),
    hovertext = dfresulrac[(dfresulrac['year']== 2008)].sort_values(by=['driverRef'])['constructorRef']
)])
fig.update_layout(title={
        'text': "Pontos Classificatórios do Mundial de 2008",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}, 
                  yaxis=dict(
                            title='Pontos',
                            titlefont_size=16,
                            tickfont_size=14),
                  xaxis=dict(
                            title='Piloto',
                            titlefont_size=16,
                            tickfont_size=14),
                  template = "plotly_dark"
                  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a96ad47f-33f3-45e7-997f-fe68cae1ffcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a96ad47f-33f3-45e7-997f-fe68cae1ffcd")) {
#                     Plotly.newPlot(
#                         'a96ad47f-33f3-45e7-997f-fe68cae1ffcd',
# ...

# %%
fig = go.Figure(data=[go.Bar(
    x=dfresulrac[(dfresulrac['year']== 2008)].sort_values(by=['constructorRef'])['constructorRef'].unique(),
    y=dfresulrac[(dfresulrac['year']== 2008)].groupby('constructorRef')['points'].sum(),
    hovertext = dfresulrac[(dfresulrac['year']== 2008)].sort_values(by=['constructorRef'])['nationality_y']
)])
fig.update_layout(title={
        'text': "Construtores do Mundial de F1 2008",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}, 
                  yaxis=dict(
                            title='Pontos',
                            titlefont_size=16,
                            tickfont_size=14),
                  xaxis=dict(
                            title='Equipe',
                            titlefont_size=16,
                            tickfont_size=14),
                  template = "plotly_dark"
                  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4fd19197-b840-4c1a-adec-7cc063f37934" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4fd19197-b840-4c1a-adec-7cc063f37934")) {
#                     Plotly.newPlot(
#                         '4fd19197-b840-4c1a-adec-7cc063f37934',
# ...

# %%
dfresulrac[(dfresulrac['position']== '1')].groupby('driverRef')['position'].value_counts()
# Out:
# driverRef  position
# alboreto   1            5
# alesi      1            1
# alonso     1           32
# angelis    1            2
# arnoux     1            7
#                        ..
# vukovich   1            2
# wallard    1            1
# ward       1            1
# watson     1            5
# webber     1            9
# Name: position, Length: 110, dtype: int64

# %%
fig = go.Figure(data=[go.Bar(
    x=dfresulrac[(dfresulrac['position']== '1')].sort_values(by=['driverRef'])['driverRef'].unique(),
    y=dfresulrac[(dfresulrac['position']== '1')].groupby('driverRef')['position'].value_counts()
    #hovertext = dfresulrac[(dfresulrac['year']== 2008)].sort_values(by=['constructorRef'])['nationality_y']
)])
fig.update_layout(title={
        'text': "Pilotos com mais Vitórias",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}, 
                  yaxis=dict(
                            title='vitorias',
                            titlefont_size=16,
                            tickfont_size=14),
                  xaxis=dict(
                            title='Piloto',
                            titlefont_size=16,
                            tickfont_size=14),
                  template = "plotly_dark"
                  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="03780f24-8591-41f8-88c0-280faa7a9c21" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("03780f24-8591-41f8-88c0-280faa7a9c21")) {
#                     Plotly.newPlot(
#                         '03780f24-8591-41f8-88c0-280faa7a9c21',
# ...

# %%
fig = go.Figure(data=[go.Bar(
    x=dfresulrac[(dfresulrac['position']== '1')].sort_values(by=['nationality_x'])['nationality_x'].unique(),
    y=dfresulrac[(dfresulrac['position']== '1')].groupby('nationality_x')['position'].value_counts()
    #hovertext = dfresulrac[(dfresulrac['year']== 2008)].sort_values(by=['constructorRef'])['nationality_y']
)])
fig.update_layout(title={
        'text': "Países com mais Vitórias",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}, 
                  yaxis=dict(
                            title='vitorias',
                            titlefont_size=16,
                            tickfont_size=14),
                  xaxis=dict(
                            title='Países',
                            titlefont_size=16,
                            tickfont_size=14),
                  template = "plotly_dark"
                  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="61048e32-33c9-46a1-93ce-55846653b1d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("61048e32-33c9-46a1-93ce-55846653b1d2")) {
#                     Plotly.newPlot(
#                         '61048e32-33c9-46a1-93ce-55846653b1d2',
# ...

# %%
fig = go.Figure(data=[go.Pie(labels=dfresulrac[(dfresulrac['position']== '1')].sort_values(by=['nationality_x'])['nationality_x'].unique(), values=dfresulrac[(dfresulrac['position']== '1')].groupby('nationality_x')['position'].value_counts(),hole=.3)])
fig.update_layout(title={
        'text': "Percentual de Vitórias por Países",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}, 
        template = "plotly_dark")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c69c1baf-3ca5-417b-a63a-ddb8b0797ea2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c69c1baf-3ca5-417b-a63a-ddb8b0797ea2")) {
#                     Plotly.newPlot(
#                         'c69c1baf-3ca5-417b-a63a-ddb8b0797ea2',
# ...

# %%
fig = go.Figure(data=[go.Bar(
    x=dfresulrac[(dfresulrac['grid']== 1)].sort_values(by=['driverRef'])['driverRef'].unique(),
    y=dfresulrac[(dfresulrac['grid']== 1)].groupby('driverRef')['grid'].value_counts()
    #hovertext = dfresulrac[(dfresulrac['year']== 2008)].sort_values(by=['constructorRef'])['nationality_y']
)])
fig.update_layout(title={
        'text': "Pilotos com mais Poles",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}, 
                  yaxis=dict(
                            title='Poles',
                            titlefont_size=16,
                            tickfont_size=14),
                  xaxis=dict(
                            title='Piloto',
                            titlefont_size=16,
                            tickfont_size=14),
                  template = "plotly_dark"
                  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4a4ea80a-5e9c-4236-b449-492cc3b3d22e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a4ea80a-5e9c-4236-b449-492cc3b3d22e")) {
#                     Plotly.newPlot(
#                         '4a4ea80a-5e9c-4236-b449-492cc3b3d22e',
# ...

# %%
pip install folium

# %%
import folium

# %%
import  plotly.graph_objects  as  go

# %%
circuitos.head()
# Out:
#    circuitId  ...                                                url
# 0          1  ...  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1          2  ...  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2          3  ...  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3          4  ...  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 4          5  ...         http://en.wikipedia.org/wiki/Istanbul_Park
#
# [5 rows x 9 columns]

# %%
coordenadas=[]
for lat,lng in zip(circuitos.lat.values,circuitos.lng.values):
  coordenadas.append([lat,lng])

# %%
mapa = folium.Map(location=[-15.788497,-47.879873],zoom_start=5,tiles='Stamen Toner')

# %%
mapa.add_child(plugins.HeatMap(coordenadas))
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
import  folium 
from  folium  import  plugins

# %%
import pandas as pd
