# %%
# !pip install sqlalchemy
# !pip install pandas
# !pip install pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\trabalho\anaconda3\lib\site-packages (1.4.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\trabalho\anaconda3\lib\site-packages (from sqlalchemy) (1.0.0)
# Requirement already satisfied: pandas in c:\users\trabalho\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\trabalho\anaconda3\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\trabalho\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\trabalho\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\trabalho\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: pymysql in c:\users\trabalho\anaconda3\lib\site-packages (1.0.2)

# %%
import pymysql
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
from matplotlib import pyplot as plt

# %%
AWS_DB_HOST = 'database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com'
AWS_DB_USER = 'admin'
AWS_DB_PASS = 'mysqladmin1509'
AWS_DB_OLTP = 'FORMULA1'
AWS_DB_OLAT = 'DW_F1'

# %%
def teste_conexao_base_pymysql(bdados):
    """
    fução para conectar uma base qualquer na instancia da AWS
    """
    try:
        pymysql.connect(host=AWS_DB_HOST,user=AWS_DB_USER,
        password=AWS_DB_PASS,
        database=bdados)
        print("Base de dados " + bdados + " conectada com sucesso!")
        
    except Exception as err:
        print("Falha na conexão")
        print(err)

# %%
teste_conexao_base_pymysql(AWS_DB_OLTP)
# Out:
# Base de dados FORMULA1 conectada com sucesso!

# %%
teste_conexao_base_pymysql(AWS_DB_OLAT)
# Out:
# Base de dados DW_F1 conectada com sucesso!

# %%
# OLTP - banco de dados transacional - FORMULA1
engine_bdf1 = sqlalchemy.create_engine('mysql+pymysql://admin:mysqladmin1509@database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com:3306/FORMULA1')
engine_bdf1
# Out:
# Engine(mysql+pymysql://admin:***@database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com:3306/FORMULA1)

# %%
engine_bdwf1 = sqlalchemy.create_engine('mysql+pymysql://admin:mysqladmin1509@database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com:3306/DW_F1')
engine_bdwf1
# Out:
# Engine(mysql+pymysql://admin:***@database-1.c2hbzw6k9btq.us-east-2.rds.amazonaws.com:3306/DW_F1)

# %%
tabela_piloto = pd.read_sql_table("dim_pilotos", engine_bdwf1)
tabela_piloto.id
# Out:
#    id_dim_piloto  code_piloto  ref_piloto abr_piloto primeiro_nome  \
# 0              1            1    hamilton        HAM         Lewis
# 1              2            2    heidfeld        HEI          Nick
# 2              3            3     rosberg        ROS          Nico
# 3              4            4      alonso        ALO      Fernando
# 4              5            5  kovalainen        KOV        Heikki
# 5              6            6    nakajima        NAK        Kazuki
# 6              7            7    bourdais        BOU     Sébastien
# 7              8            8   raikkonen        RAI          Kimi
# 8              9            9      kubica        KUB        Robert
# 9             10           10       glock        GLO          Timo
#
#   ultimo_nome nacionalidade data_nascimento
# 0    Hamilton       British      1985-01-07
# 1    Heidfeld        German      1977-05-10
# 2     Rosberg        German      1985-06-27
# 3      Alonso       Spanish      1981-07-29
# 4  Kovalainen       Finnish      1981-10-19
# 5    Nakajima      Japanese      1985-01-11
# 6    Bourdais        French      1979-02-28
# 7   Räikkönen       Finnish      1979-10-17
# 8      Kubica        Polish      1984-12-07
# 9       Glock        German      1982-03-18

# %%
coluna_pilotos = pd.read_sql_table("pilotos", engine_bdf1, columns=['id_piloto', 'ref_piloto'])
coluna_pilotos.head(10)
# Out:
#    id_piloto  ref_piloto
# 0          1    hamilton
# 1          2    heidfeld
# 2          3     rosberg
# 3          4      alonso
# 4          5  kovalainen
# 5          6    nakajima
# 6          7    bourdais
# 7          8   raikkonen
# 8          9      kubica
# 9         10       glock

# %%
tabela_circuitos = pd.read_sql_table("dim_circuitos", engine_bdwf1)
tabela_circuitos
# Out:
#     id_dim_circuito  code_circuito ref_circuito  \
# 0                 1              1  albert_park
# 1                 2              2       sepang
# 2                 3              3      bahrain
# 3                 4              4    catalunya
# 4                 5              5     istanbul
# ..              ...            ...          ...
# 72               73             73          BAK
# 73               74             74        hanoi
# 74               75             75     portimao
# 75               76             76      mugello
# 76               77             77       jeddah
#
#                            nome_circuito localizacao_circuito pais_circuito
# 0         Albert Park Grand Prix Circuit            Melbourne     Australia
# 1           Sepang International Circuit         Kuala Lumpur      Malaysia
# 2          Bahrain International Circuit               Sakhir       Bahrain
# 3         Circuit de Barcelona-Catalunya             Montmeló         Spain
# 4                          Istanbul Park             Istanbul        Turkey
# ..                                   ...                  ...           ...
# 72                     Baku City Circuit                 Baku    Azerbaijan
# 73                  Hanoi Street Circuit                Hanoi       Vietnam
# 74    Autódromo Internacional do Algarve             Portimão      Portugal
# 75  Autodromo Internazionale del Mugello              Mugello         Italy
# 76                 Jeddah Street Circuit               Jeddah  Saudi Arabia
#
# [77 rows x 6 columns]

# %%
coluna_circuitos = pd.read_sql_table("dim_circuitos", engine_bdwf1, columns=['localizacao_circuito','pais_circuito'])
coluna_circuitos.head(10)
# Out:
#   localizacao_circuito pais_circuito
# 0            Melbourne     Australia
# 1         Kuala Lumpur      Malaysia
# 2               Sakhir       Bahrain
# 3             Montmeló         Spain
# 4             Istanbul        Turkey
# 5          Monte-Carlo        Monaco
# 6             Montreal        Canada
# 7          Magny Cours        France
# 8          Silverstone            UK
# 9           Hockenheim       Germany

# %%
tabela_circuitos = pd.read_sql('dim_circuitos', engine_bdwf1)

tabela_circuito_analise = tabela_circuitos.query('pais_circuito =="Australia"')

total_circuito_analise = len(tabela_circuito_analise)
print("A quantidade de circuitos que aconteceram na Australia é de:", total_circuito_analise)

tabela_circuito_analise
# Out:
# A quantidade de circuitos que aconteceram na Australia é de: 2
#     id_dim_circuito  code_circuito ref_circuito  \
# 0                 1              1  albert_park
# 28               29             29     adelaide
#
#                      nome_circuito localizacao_circuito pais_circuito
# 0   Albert Park Grand Prix Circuit            Melbourne     Australia
# 28         Adelaide Street Circuit             Adelaide     Australia

# %%
tabela_pilotos = pd.read_sql_table("dim_pilotos", engine_bdwf1)
tabela_pilotos
# Out:
#      id_dim_piloto  code_piloto         ref_piloto abr_piloto primeiro_nome  \
# 0                1            1           hamilton        HAM         Lewis
# 1                2            2           heidfeld        HEI          Nick
# 2                3            3            rosberg        ROS          Nico
# 3                4            4             alonso        ALO      Fernando
# 4                5            5         kovalainen        KOV        Heikki
# ..             ...          ...                ...        ...           ...
# 848            849          850  pietro_fittipaldi        FIT        Pietro
# 849            850          851             aitken        AIT          Jack
# 850            851          852            tsunoda        TSU          Yuki
# 851            852          853            mazepin        MAZ        Nikita
# 852            853          854    mick_schumacher        MSC          Mick
#
#     ultimo_nome nacionalidade data_nascimento
# 0      Hamilton       British      1985-01-07
# 1      Heidfeld        German      1977-05-10
# 2       Rosberg        German      1985-06-27
# 3        Alonso       Spanish      1981-07-29
# 4    Kovalainen       Finnish      1981-10-19
# ..          ...           ...             ...
# 848  Fittipaldi     Brazilian      1996-06-25
# 849      Aitken       British      1995-09-23
# 850     Tsunoda      Japanese      2000-05-11
# 851     Mazepin       Russian      1999-03-02
# 852  Schumacher        German      1999-03-22
#
# [853 rows x 8 columns]

# %%
tabela_pilotos = pd.read_sql('dim_pilotos', engine_bdwf1)

tabela_pilotos_analise = tabela_pilotos.query('nacionalidade =="Brazilian"')

total_pilotos_analise = len(tabela_pilotos_analise)
print("a quantidade de pilotos no brasil:", total_pilotos_analise)

tabela_pilotos_analise
# Out:
# a quantidade de pilotos no brasil: 32
#      id_dim_piloto  code_piloto          ref_piloto abr_piloto primeiro_nome  \
# 11              12           12           piquet_jr        PIQ        Nelson
# 12              13           13               massa        MAS        Felipe
# 21              22           22         barrichello        BAR        Rubens
# 40              41           41               zonta        ZON       Ricardo
# 41              42           42            pizzonia        PIZ       Antônio
# 42              43           43               matta         -1     Cristiano
# 53              54           54               burti         -1       Luciano
# 57              58           58             marques         -1         Tarso
# 58              59           59            bernoldi         -1       Enrique
# 63              64           64               diniz         -1         Pedro
# 72              73           73              rosset         -1       Ricardo
# 89              90           90              moreno         -1       Roberto
# 101            102          102               senna         -1        Ayrton
# 103            104          104          fittipaldi         -1     Christian
# 126            127          127            gugelmin         -1      Maurício
# 136            137          137              piquet         -1        Nelson
# 191            192          192               serra         -1         Chico
# 195            196          196              boesel         -1          Raul
# 223            224          224  emerson_fittipaldi         -1       Emerson
# 236            237          237             ribeiro         -1          Alex
# 249            250          250                pace         -1        Carlos
# 252            253          253            hoffmann         -1          Ingo
# 289            290          290   wilson_fittipaldi         -1        Wilson
# 330            331          331               bueno         -1          Luiz
# 566            567          567                orey         -1         Fritz
# 621            622          622               landi         -1         Chico
# 623            624          624               ramos         -1      Hernando
# 745            746          746              bianco         -1          Gino
# 808            809          810              grassi        DIG         Lucas
# 809            810          811         bruno_senna        SEN         Bruno
# 829            830          831                nasr        NAS        Felipe
# 848            849          850   pietro_fittipaldi        FIT        Pietro
#
#         ultimo_nome nacionalidade data_nascimento
# 11       Piquet Jr.     Brazilian      1985-07-25
# 12            Massa     Brazilian      1981-04-25
# 21      Barrichello     Brazilian      1972-05-23
# 40            Zonta     Brazilian      1976-03-23
# 41         Pizzonia     Brazilian      1980-09-11
# 42         da Matta     Brazilian      1973-09-19
# 53            Burti     Brazilian      1975-03-05
# 57          Marques     Brazilian      1976-01-19
# 58         Bernoldi     Brazilian      1978-10-19
# 63            Diniz     Brazilian      1970-05-22
# 72           Rosset     Brazilian      1968-07-27
# 89           Moreno     Brazilian      1959-02-11
# 101           Senna     Brazilian      1960-03-21
# 103      Fittipaldi     Brazilian      1971-01-18
# 126        Gugelmin     Brazilian      1963-04-20
# 136          Piquet     Brazilian      1952-08-17
# 191           Serra     Brazilian      1957-02-03
# 195          Boesel     Brazilian      1957-12-04
# 223      Fittipaldi     Brazilian      1946-12-12
# 236         Ribeiro     Brazilian      1948-11-07
# 249            Pace     Brazilian      1944-10-06
# 252        Hoffmann     Brazilian      1953-02-28
# 289      Fittipaldi     Brazilian      1943-12-25
# 330           Bueno     Brazilian      1937-01-16
# 566          d Orey     Brazilian      1938-03-25
# 621           Landi     Brazilian      1907-07-14
# 623  da Silva Ramos     Brazilian      1925-12-07
# 745          Bianco     Brazilian      1916-07-22
# 808       di Grassi     Brazilian      1984-08-11
# 809           Senna     Brazilian      1983-10-15
# 829            Nasr     Brazilian      1992-08-21
# 848      Fittipaldi     Brazilian      1996-06-25

# %%
tabela_fato = pd.read_sql('fato_resultados', engine_bdwf1)
tabela_fato
# Out:
#        id_dim_construtor  id_dim_piloto  id_dim_corrida  id_dim_circuito  \
# 0                      2              9               1                1
# 1                      1              5               1                1
# 2                      2              2               1                1
# 3                      1              1               1                1
# 4                      2              9               2                2
# ...                  ...            ...             ...              ...
# 25035                181            347             699               56
# 25036                170            414             699               56
# 25037                179            346             699               56
# 25038                 65            328             699               56
# 25039                168            360             699               56
#
#        id_dim_tempo temporada  pontos_ganhos  qtd_voltas  grid  ordem_posicao  \
# 0                 1      2009              0          55     4             14
# 1                 1      2009              0           0    12             19
# 2                 1      2009              0          58     9             10
# 3                 1      2009              0          58    18             20
# 4                 2      2009              0           1     6             19
# ...             ...       ...            ...         ...   ...            ...
# 25035           699      1965              0          42     7             17
# 25036           699      1965              0           0     0             26
# 25037           699      1965              0          83    14              7
# 25038           699      1965              1          83    11              6
# 25039           699      1965              2          84     8              5
#
#        ranking  volta_rapida tempo_de_volta tempo_volta_rapida  \
# 0          2.0          36.0       1:27.988            216.970
# 1          NaN           NaN           null               null
# 2          5.0          48.0       1:28.283            216.245
# 3         13.0          39.0       1:29.020            214.455
# 4          NaN           NaN           null               null
# ...        ...           ...            ...                ...
# 25035      NaN           NaN           null               null
# 25036      NaN           NaN           null               null
# 25037      NaN           NaN           null               null
# 25038      NaN           NaN           null               null
# 25039      NaN           NaN           null               null
#
#                    status
# 0               Collision
# 1               Collision
# 2                Finished
# 3            Disqualified
# 4                  Engine
# ...                   ...
# 25035              Clutch
# 25036  Did not prequalify
# 25037             +2 Laps
# 25038             +2 Laps
# 25039              +1 Lap
#
# [25040 rows x 15 columns]

# %%
tabela_construtores = pd.read_sql('dim_construtores', engine_bdwf1)
tabela_construtores
# Out:
#      id_dim_construtor  code_construtor nome_construtor fabricante_motor  \
# 0                    1                1         McLaren         Mercedes
# 1                    2                2      BMW Sauber       BMW Sauber
# 2                    3                3        Williams         Mercedes
# 3                    4                4         Renault          Renault
# 4                    5                5      Toro Rosso       Toro Rosso
# ..                 ...              ...             ...              ...
# 206                207              209  Manor Marussia   Manor Marussia
# 207                208              210    Haas F1 Team          Ferrari
# 208                209              211    Racing Point     Racing Point
# 209                210              213      AlphaTauri            Honda
# 210                211              214  Alpine F1 Team          Renault
#
#     nacionalidade_construtor
# 0                    British
# 1                     German
# 2                    British
# 3                     French
# 4                    Italian
# ..                       ...
# 206                  British
# 207                 American
# 208                  British
# 209                  Italian
# 210                   French
#
# [211 rows x 5 columns]
